# %% [markdown]
# ## <center><B><h4>Recognizing Handwritten Digits</h4></B></center>
# <h5>suvenconsultants Internship Project-2</h5>
# <h5>Jayasurya V </h5>

# %% [markdown]
# #### Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Load dataset from sklearn

# %%
from sklearn.datasets import load_digits

# %%
digit=load_digits()

# %% [markdown]
# ### shape of the Dataset

# %%
print(digit.data.shape)
# Out:
# (1797, 64)

# %% [markdown]
# ### Visualizing the images and labels in our Dataset

# %%
plt.figure(figsize=(20,4))
for index,(image,label)in enumerate(zip(digit.data[0:5],digit.target[0:5])):
    plt.subplot(1, 5 ,index+1)
    plt.imshow(np.reshape(image,(8,8)),cmap=plt.cm.gray)
    plt.title('training:%i\n'%label,fontsize=20)

# %% [markdown]
# ### Split train and test

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(digit.data,digit.target,test_size=0.20)

# %% [markdown]
# # <h5>In scikitlearn four step modelling pattern</h5>
# <tab><h6> 1. Import the model</h6></tab>
# <tab><h6> 2. Making the instance</h6></tab>
# <tab><h6> 3. Training the model</h6></tab>
# <tab><h6> 4. Predicting the new label data</h6></tab>

# %% [markdown]
# #### Importing the model

# %%
from sklearn.linear_model import LogisticRegression

# %% [markdown]
# #### Making the instance

# %%
LR=LogisticRegression()

# %% [markdown]
# #### Training the model

# %%
LR.fit(x_train,y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %% [markdown]
# #### Predicting the new label data

# %%
prediction=LR.predict(x_test)

# %%
y_test[5]
# Out:
# 1

# %%
prediction[5]
# Out:
# 1

# %% [markdown]
# #### Accuarcy check

# %%
from sklearn.metrics import accuracy_score

# %%
print(accuracy_score(y_test,prediction)*100)
# Out:
# 93.61111111111111
